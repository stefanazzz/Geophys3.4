# %% [markdown]
# ERT modeling and inversion in 2D
# ================================

# %% [markdown]
# This code uses the open-source library: <br/> pyGIMLi (www.pygimli.org) and PyBERT (https://pypi.org/project/PyBERT/) to create mesh, perform forward modeling and run the inversion.
#
# A number of python libraries such as matplotlib, numpy, pandas are also used. The file geo05.yml is a list of describing python environment where all necessary libraries are installed. The yml file can be used to re-create the proper environment with conda. Note that geo05 uses "jupyter lab", not "jupyer notebook"
#
# **To run, this code requires the companion file:**<br>
# Init_ERT2D.py

# %% [markdown]
# ## Initialisation cells

# %%
# %matplotlib ipympl
from matplotlib import pyplot as plt
from Init_ERT2D_3_5 import *

# %% [markdown]
# ## Read the data file from TIGRE
# You need to edit the name of input file here to match your input data file.<br>
# That would be the file uploaded in the same folder as this code, and it will be either the **res** or **dat** file from the tigre array.

# %%
#example file 1:
input_file='./FlassVale01_interp.dat'

#example file 2:
#input_file='./c1_1m.res'

dx,Nread,Nel,elpos,readings = read_dat(input_file)
# Out:
#                                            0
# 0  Harry flass vale bower: Line 1 / Spread 1
# 1                                       0.25
# 2                                          1
# 3                                        650
# 4                                          1
# 5                                          0
# tot readings:  650.0 || el. spacing dx=  0.25 || nr. of electrodes  Nel =  63

# %% [markdown]
# ## Input topography vector with n=Nel values.
# If you known the topography (relative elevation for each electrode) you should input it here using
# <code>
# topography = [z_1, z_2, .... z_Nel]
# </code>
# where 1, 2, ... Nel is are the electrodes and z is their elevation.
# If topography is negligible just use
# <code>
# topography = np.zeros(Nel)
# </code>
# make sure the topography vector has the same number of values as the number of electrodes.

# %% [raw]
# # case with no topography:
# topography = np.zeros(Nel) # no topography

# %%
# case with known topography for "FlassVale01_interp.dat" example (63 electrodes):
topography=[70.2083781 , 70.25612936, 70.29714876, 70.33390108, 70.37253795,
       70.42013276, 70.48375885, 70.56810439, 70.66831675, 70.77715812,
       70.88739067, 70.99401378, 71.10097568, 71.21446183, 71.34065765,
       71.48262625, 71.63094135, 71.77305433, 71.89641657, 71.99142024,
       72.06022059, 72.1079137 , 72.1395956 , 72.16003001, 72.17265119,
       72.18056108, 72.18686159, 72.19424756, 72.20378544, 72.2161346 ,
       72.23195441, 72.2507575 , 72.26746962, 72.2758698 , 72.26973708,
       72.24455895, 72.20265694, 72.14806104, 72.08480125, 72.01659512,
       71.9459104 , 71.87490236, 71.80572631, 71.73903095, 71.66943862,
       71.59006507, 71.49402606, 71.37944692, 71.2644913 , 71.17233244,
       71.12614357, 71.13826896, 71.17773707, 71.2027474 , 71.17149943,
       71.05677538, 70.88968824, 70.71593373, 70.58120754, 70.51859371,
       70.51072949, 70.52764048, 70.53935227]
len(topography),Nel
# Out:
# (63, 63)

# %% [markdown]
# ## Validate and check topography

# %%
elpos=make_topo(topography,elpos,Nel,dx)
fig,ax=plt.subplots(figsize=(8,1))
ax.plot(elpos[:,0],elpos[:,2]);ax.plot(elpos[:,0],elpos[:,2],'.');ax.set_aspect('equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Give error, re-format data and save to new file.
# The estimate of average error will be used in case some or all of the original data has no error

# %%
# Give average error estmate (usually 2 or 3 %):
err_avg=0.03 

# Organise resistivity and corresponding electrode indexes, PYBERT-unified style, in array abmnr:
abmnr=make_abmnr(input_file,readings,dx,err_avg)

# Write formatted uni2 file:
filout=write_formatted(err_avg,input_file,Nel,elpos,Nread,abmnr)
print('Formatted data saved in file:\n',filout)
# Out:
# Formatted data saved in file:
#  ./FlassVale01_interp_uni2.csv

# %% [markdown]
# # Run inversion to estimate the model.
#
# In the next cell, the formatted data is imported,  the manager is set up and the inversion is performed <br>
# A mesh is created on-the-fly based on the sensor positions <br>
# The `invert` function returns the model estimate. A number of options can be modified as needed:
#
# ### OPTIONAL PARAMETERS AND SOME INDICATIVE VALUES:
# <code>
#  maxIter=12             | Will stop after maxIter cycles if not converged yet
#  quality = 28           | Quality of the mesh. lower if code crashes.
#  useGradient=True       | Inital model has a vertical velocity gradient or not
#  vTop=150, vBottom=3000 | Initial model gradient is imposed by setting top and bottom velocities.
#                           Usually leave these out by commenting them with #
#  limits=[150,3000]      | Limits to max and min possible velocities in model.
#                           Use max min estimates from linear fit of arrival times.
#  paraMaxCellSize=10     | Limit the size of the cells in the mesh. Small look nicer but slower.
#                           Increase if code crashes. Start testing with large values.
#                           When happy with result, reduce to approximate geophone spacing.
#  paraDepth=50           | Likely penetration depth of the survey, plus some
#  zWeight=0.1            | 0-1, smaller value will perfer layered solution.
#  lam= 50                | Regularisation parameter, will prefer smoother (reduced curvature) solutions if large
#                           Large lam will also converge faster.
#  cType=1                | Set the type of mninimisation process, should not make a big difference
#  verbose=1              | Printout a lot of info if set to 1
# </code>

# %%
mgr = ert.ERTManager()
data = mgr.load(filout)
data['k'] = ert.createGeometricFactors(data, numerical=True)
model = mgr.invert(data, maxIter=12, quality = 30,
          useGradient=False, #vTop=150, vBottom=300, 
          #limits=[100,3800],
          paraMaxCellSize=0.125, paraDepth=4,
          zWeight=0.2, lam= 150, cType=1, 
          verbose=1)
#
# Out:
# ./core/src/bert/bertDataContainer.cpp:107		virtual void GIMLI::DataContainerERT::checkDataValidityLocal()  In datafile zero current or voltage found.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Cache /home/stefan/anaconda3/envs/geo05/lib/python3.11/site-packages/pygimli/physics/ert/ert.py:createGeometricFactors restored (12.5s x 4): /home/stefan/.cache/pygimli/18204754027079216845
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Found 2 regions.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Found 2 regions.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 3787 Cells: 7256 Boundaries: 5600
# Warning: removed 20 values due to sensor index out of bounds!
# Data validity check: found 22 invalid data.
# Data validity check: remove invalid data.
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Use median(data values)=860.5563500000001
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Created startmodel from forward operator: 1444, min/max=860.556350/860.556350
# 26/05/24 - 13:35:03 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  3
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  4
#
# Statistics:
#
#   Input vertices: 133
#   Input segments: 134
#   Input holes: 0
#
#   Mesh vertices: 987
#   Mesh triangles: 1814
#   Mesh edges: 2800
#   Mesh exterior boundary edges: 158
#   Mesh interior boundary edges: 49
#   Mesh subsegments (constrained edges): 207
#
# min/max(dweight) = 33.3333/33.3333
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x7f0be70cf1a0>
# Data transformation: <pgcore._pygimli_.RTransLogLU object at 0x7f0bdef2aed0>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x7f0bdef595b0>
# min/max (data): 181/1591
# min/max (error): 3%/3%
# min/max (start model): 861/861
# --------------------------------------------------------------------------------
# use model trans from RegionManager
# Calculating response for model: min = 860.556 max = 860.556
# Allocating memory for primary potential...... 0.0170455
#
# No primary potential for secondary field calculation with topography.
# Creating P2-Primmesh:		Nodes: 14829	Cells: 7256	Boundaries: 11042
# ModellingBase::setMesh() copying new mesh ... Found topography for surface=70.2084 : 70.2502
# Found datafile: 63 electrodes
# Found: 63 node-electrodes
# rMin = 0.125038, rMax = 31.0071
# NGauLeg + NGauLag for inverse Fouriertransformation: 14 + 4
# Found non-Neumann domain
# 0.0406856 s
# FOP updating mesh dependencies ... 2.345e-06 s
# Forward: time: 22.5566s
# Interpolating to secondary mesh
#
# 1134 	/ 113414 	/ 1134
# Forward: time: 27.6553s
# Response: min = 856.719 max = 863.756 mean = 860.53
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 33.3333/33.3333
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 2078 x 1444
# check Jacobian: wrong dimensions: (0x0) should be (628x1444)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# inv.iter 0 ... chi² =   86.81
# --------------------------------------------------------------------------------
# inv.iter 1 ... S(16/16-std::mt): 0.0123226:time: 1.14898s
# sens sum: median = 0.975442 min = 0.606224 max = 1.01647
# ... 1.16041 s
# min data = 181 max data = 1591.47 (628)
# min error = 0.03 max error = 0.03 (628)
# min response = 856.719 max response = 863.756 (628)
# calc without reference model
# 0: rms/rrms(data, response) = 231.879/36.5056%
# 0: chi^2(data, response, error, log) = 86.8105
# 0: Phi = 54517 + 0 * 150 = 54517
# solve CGLSCDWWtrans with lambda = 150
# Calculating response for model: min = 95.7986 max = 6426.38
# Using existing primary potentials.
# Forward: time: 2.80634s
# Response: min = 233.412 max = 1747.73 mean = 909.125
# Reciprocity rms(modelReciprocity) 1.56752%, max: 10.3854%
# 1: LS newModel: min = 95.7986; max = 6426.38
# 1: LS newResponse: min = 228.555; max = 1747.83
# 1: rms/rrms(data, LS newResponse) = 138.482/17.2488%
# 1: chi^2(data, LS newResponse, error, log) = 25.1179
# 1: Phi = 15774+12.9684*150=17719.3
# Performing line search with tau = 0.81
# Calculating response for model: min = 145.381 max = 4385.92
# Using existing primary potentials.
# Forward: time: 2.80888s
# Response: min = 304.889 max = 1550.97 mean = 897.032
# Reciprocity rms(modelReciprocity) 1.25495%, max: 8.01909%
# chi² =   19.67 (dPhi = 75.00%) lam: 150.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 145.381; max = 4385.92
# 1: Response: min = 299.766; max = 1550.87
# 1: rms/rrms(data, Response) = 116.567/15.6694%
# 1: chi^2(data, Response, error, log) = 19.6704
# 1: Phi = 12353+8.50854*150=13629.3
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(16/16-std::mt): 0.00141872:time: 1.1099s
# sens sum: median = 1.18613 min = 0.931403 max = 1.67929
# ... 1.12089 s
# solve CGLSCDWWtrans with lambda = 150
# Calculating response for model: min = 99.0386 max = 4547.34
# Using existing primary potentials.
# Forward: time: 2.78869s
# Response: min = 245.836 max = 1601.58 mean = 857.438
# Reciprocity rms(modelReciprocity) 1.5557%, max: 11.7577%
# 2: LS newModel: min = 99.0386; max = 4547.34
# 2: LS newResponse: min = 240.094; max = 1589.93
# 2: rms/rrms(data, LS newResponse) = 65.9514/9.89347%
# 2: chi^2(data, LS newResponse, error, log) = 7.48681
# 2: Phi = 4701.72+12.5452*150=6583.49
# Performing line search with tau = 0.81
# Calculating response for model: min = 106.532 max = 3803.87
# Using existing primary potentials.
# Forward: time: 2.98519s
# Response: min = 257.163 max = 1577.13 mean = 864.298
# Reciprocity rms(modelReciprocity) 1.47746%, max: 11.0087%
# 2: Model: min = 106.532; max = 3803.87
# 2: Response: min = 251.426; max = 1566.05
# 2: rms/rrms(data, Response) = 63.3111/9.95082%
# 2: chi^2(data, Response, error, log) = 6.99963
# 2: Phi = 4395.77+11.0148*150=6047.98
# chi² =    7.00 (dPhi = 55.63%) lam: 150.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(16/16-std::mt): 0.00143113:time: 1.09235s
# sens sum: median = 1.26656 min = 0.805053 max = 2.3232
# ... 1.10335 s
# solve CGLSCDWWtrans with lambda = 150
# Calculating response for model: min = 101.068 max = 4697.24
# Using existing primary potentials.
# Forward: time: 2.94866s
# Response: min = 254.505 max = 1714.16 mean = 901.092
# Reciprocity rms(modelReciprocity) 1.51226%, max: 10.8383%
# 3: LS newModel: min = 101.068; max = 4697.24
# 3: LS newResponse: min = 248.498; max = 1702.38
# 3: rms/rrms(data, LS newResponse) = 49.4604/9.06822%
# 3: chi^2(data, LS newResponse, error, log) = 5.18482
# 3: Phi = 3256.07+12.3373*150=5106.67
# Performing line search with tau = 0.73
# Calculating response for model: min = 102.515 max = 4370.6
# chi² =    5.04 (dPhi = 18.38%) lam: 150.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Using existing primary potentials.
# Forward: time: 2.84963s
# Response: min = 255.362 max = 1677.54 mean = 890.795
# Reciprocity rms(modelReciprocity) 1.49861%, max: 10.8855%
# 3: Model: min = 102.515; max = 4370.6
# 3: Response: min = 249.426; max = 1665.94
# 3: rms/rrms(data, Response) = 47.4503/9.01186%
# 3: chi^2(data, Response, error, log) = 5.03665
# 3: Phi = 3163.02+11.8242*150=4936.64
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(16/16-std::mt): 0.0013586:time: 1.14506s
# sens sum: median = 1.34229 min = 0.873726 max = 2.45777
# ... 1.15645 s
# solve CGLSCDWWtrans with lambda = 150
# Calculating response for model: min = 101.88 max = 5006.86
# Using existing primary potentials.
# Forward: time: 2.74631s
# Response: min = 256.065 max = 1664.55 mean = 886.191
# Reciprocity rms(modelReciprocity) 1.52665%, max: 10.8579%
# 4: LS newModel: min = 101.88; max = 5006.86
# 4: LS newResponse: min = 249.754; max = 1653.62
# 4: rms/rrms(data, LS newResponse) = 45.098/8.70733%
# 4: chi^2(data, LS newResponse, error, log) = 4.72067
# 4: Phi = 2964.58+12.4324*150=4829.43
# Performing line search with tau = 0.74
# Calculating response for model: min = 102.045 max = 4833.02
# Using existing primary potentials.
# Forward: time: 2.79304s
# Response: min = 255.899 max = 1668.19 mean = 887.392
# Reciprocity rms(modelReciprocity) 1.51826%, max: 10.865%
# chi² =    4.74 (dPhi = 2.48%) lam: 150.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... 4: Model: min = 102.045; max = 4833.02
# 4: Response: min = 249.686; max = 1657.08
# 4: rms/rrms(data, Response) = 45.2462/8.7561%
# 4: chi^2(data, Response, error, log) = 4.74272
# 4: Phi = 2978.43+12.2379*150=4814.11
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(16/16-std::mt): 0.00163317:time: 1.1772s
# sens sum: median = 1.35638 min = 0.859443 max = 2.51085
# ... 1.18918 s
# solve CGLSCDWWtrans with lambda = 150
# Calculating response for model: min = 99.8003 max = 4916.18
# Using existing primary potentials.
# Forward: time: 2.9118s
# Response: min = 256.118 max = 1683.88 mean = 891.605
# Reciprocity rms(modelReciprocity) 1.5236%, max: 10.7517%
# 5: LS newModel: min = 99.8003; max = 4916.18
# 5: LS newResponse: min = 249.767; max = 1672.94
# 5: rms/rrms(data, LS newResponse) = 44.8618/8.64631%
# 5: chi^2(data, LS newResponse, error, log) = 4.65212
# 5: Phi = 2921.53+12.4459*150=4788.41
# Performing line search with tau = 0.8
# Calculating response for model: min = 101.868 max = 4899.44
# Using existing primary potentials.
# Forward: time: 2.77223s
# Response: min = 256.077 max = 1680.79 mean = 890.797
# Reciprocity rms(modelReciprocity) 1.52226%, max: 10.7743%
# 5: Model: min = 101.868; max = 4899.44
# 5: Response: min = 249.754; max = 1669.81
# 5: rms/rrms(data, Response) = 44.8578/8.66477%
# 5: chi^2(data, Response, error, log) = 4.66309
# 5: Phi = 2928.42+12.3934*150=4787.43
# chi² =    4.66 (dPhi = 0.55%) lam: 150.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.55 (< 2.0%)                 #
# ################################################################################

# %% [markdown]
# ## Plot the result

# %%
mgr.showResult()#(coverage=ert.coverage())
fig2=plt.gcf()
ax2 = fig2.axes[0]
ax2.plot(elpos[:,0],elpos[:,2],'ro',ms=3);
#fig.axes[0].set(ylim=(-45.0, 0.0))
#fig.set_size_inches(6,3);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
mgr.showData();
# Out:
# Detecting small distances, using mm accuracy
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
